# %% [markdown]
# <a href="https://colab.research.google.com/github/jhportfolio1/MS-AI-School-Azure-and-Cloud/blob/main/Azure03_PaaS_%EC%8B%A4%EC%8A%B5_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. PaaS 환경 구축하기

# %% [markdown]
# - PaaS 아래는 이미 IaaS(가상머신/가상네트워크)이 깔려있는 것

# %% [markdown]
# >## 1) 웹앱 만들기

# %% [markdown]
# >>### (1) 리소스 만들기 - 웹앱 만들기

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# >>### (2) 설정

# %% [markdown]
# - 리소스 그룹 : 공용 클라우드라면 내 리소스 그룹 잘 선택하기
# - 이름 : 내가 사용할 웹앱의 이름
# - 런타임스택 : 사용할 언어
# - 지역 : 클라우드 위치

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# >## 2) 배포완료

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# >## 3) 배포한 WordPress 도메인으로 이동

# %% [markdown]
# - 배포된 워드프레스 앱으로가면 기본 도메인이 있음
# - 도메인을 인터넷 창에 입력

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - 도메인 주소 뒤에 '/wp-admin' 입력

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - 로그인 창이 나옴

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# >## 4) 워드프레스 어드민 사이트로 이동

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# >## 5) WordPress 테마 사이트 : https://webpus.com/best-wordpress-themes/

# %% [markdown]
# # 2. Github 클론 및 VS Code 연결

# %% [markdown]
# >## 1) Github 클론

# %% [markdown]
# >>### (1) 로컬컴퓨터에 새폴더를 추가하고 cmd를 실행시킨다.

# %% [markdown]
# - 파일 경로에서 'cmd' 치면 창이 뜸

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# >>### (2) 클론할 깃허브 주소를 입력하고 엔터

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - 그럼 아까 새폴더에 다음과 같이 파일이 생성됨

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# >>### (3) 생성된 파일로 들어가서 경로창에 cmd 입력

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# >>### (4) cmd 창에 PIP 플라스크 실행

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# >## 2) VS Code 에서 Azure Tool 사용

# %% [markdown]
# >>### (1) VS Code에서 Azure Tool 설치

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# >>### (2) Azure Tool 에서 Azure 로그인

# %% [markdown]
# - Sign In 버튼 누르고, 나타나는 로그인 창을 '시크릿창'에서 실행후 로그인 해야 연동됨

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 3. 웹앱 만들기

# %% [markdown]
# >## 1) Azure에서 웹앱 만들기

# %% [markdown]
# - Github 따로 설정안해도 같이 됨

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - 논외로 (설정X) 가상네트워크도 붙일 수 있음

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# >## 2)웹앱 : 스케일업 / 스케일아웃

# %% [markdown]
# - 스케일업 : 트래픽 초과시 네트워크 수를 늘려줄 수 있음
# - 스케일아웃 : 네트워크 수를 줄임

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 4. 웹앱 - VS Code 연결

# %% [markdown]
# >## 1) VS Code - Azure Tool 에서 아까 만들어둔 웹앱 연결

# %% [markdown]
# - 애져툴에서 만들어둔 웹앱을 찾는다

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 5. SQL 데이터베이스

# %% [markdown]
# >## 1) SQL 데이터베이스 만들기

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# - 배포완료

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# >## 2) SSMS(SQL Server Management Studio) 다운로드

# %% [markdown]
# - https://learn.microsoft.com/ko-kr/sql/ssms/download-sql-server-management-studio-ssms?view=sql-server-ver16

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# >## 3) my SQL Data 들어가기

# %% [markdown]
# >>### (1) 위에 설치한 SQL Server 열기

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# >>### (2) 애져 포털의 서버 이름, 만들때 사용한 ID/PW로 로그인

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# >>### (3) 애져포털 - 쿼리편집기(미리보기) 에서도 가능함

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# >## 4) 쿼리 작업

# %% [markdown]
# >>### (1) 애져포털 쿼리 미리보기에서 작업

# %% [markdown]
# - 쿼리편집기 창에 다음 쿼리 입력

# %% [markdown]
# SELECT TOP 20 pc.Name as CategoryName, p.name as ProductName
# FROM SalesLT.ProductCategory pc
# JOIN SalesLT.Product p
# ON pc.productcategoryid = p.productcategoryid;

# %% [markdown]
# - 실행 누르면 아래 결과 뜸

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# >>### (2) SSMS(SQL Server Management Studio) 활용해서 입력

# %% [markdown]
# - 로그인 후 mySampleDatabase 우클릭 -> 새쿼리

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - 아래 쿼리 붙여넣기

# %% [markdown]
# SELECT pc.Name as CategoryName, p.name as ProductName
# FROM [SalesLT].[ProductCategory] pc
# JOIN [SalesLT].[Product] p
# ON pc.productcategoryid = p.productcategoryid;

# %% [markdown]
# - 실행 누르면 아래 결과값 확인할 수 있음

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# >>### (3) SSMS 로 데이터 베이스 연습

# %% [markdown]
# - 연습 데이터 제공 사이트 : https://www.sqlservertutorial.net/sql-server-basics/

# %% [markdown]
# - SSMS 데이터 베이스에서 새데이터베이스 추가

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - 새데이터베이스 생성완료

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - 새쿼리 만들기 - 다운받은 자료 드래그 후 실행

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - 실행하면 테이블 폴더 아래 관련 프레임이 들어감

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - Bikestore 에서 새쿼리 열어서 SELECT문 등 넣어보면 됨

# %% [markdown]
# - SELECT : https://www.sqlservertutorial.net/sql-server-basics/sql-server-select/
# - UPDATE : https://www.sqlservertutorial.net/sql-server-basics/sql-server-update/
# - DELETE : https://www.sqlservertutorial.net/sql-server-basics/sql-server-delete/

# %% [markdown]
# >## 5) VS Code에서 SQL 작업하기

# %% [markdown]
# >>### (1) VS Code 앱에서 SQL Server 인스톨

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# >>### (2) 새파일 하나 만들고, Ctrl+Shift+P 입력 후 MS SQL Connect 클릭

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# >>### (3) Azure 에서 만든 SQL데이터베이스 서버명 긁어와서 붙이기

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# >>### (4) 데이터베이스 명 그대로 넣기

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# >>### (5) SQL 데이터 베이스 만들때 ID / PW 순차적으로 넣기

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# >>### (6) 옵션 : 내가 설정하고 싶은 이름

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# >>### (7) 연결 완료

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# >>### (8) 창에 쿼리데이터 입력 후 실행

# %% [markdown]
# SELECT pc.Name as CategoryName, p.name as ProductName
# FROM [SalesLT].[ProductCategory] pc
# JOIN [SalesLT].[Product] p
# ON pc.productcategoryid = p.productcategoryid;

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - 업데이트

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - 데이터 삭제

# %% [markdown]
# ![image.png](data:image/png;base64,...)
