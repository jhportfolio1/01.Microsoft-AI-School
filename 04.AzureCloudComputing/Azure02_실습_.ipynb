# %% [markdown]
# <a href="https://colab.research.google.com/github/jhportfolio1/MS-AI-School-Azure-and-Cloud/blob/main/Azure02_%EC%8B%A4%EC%8A%B5_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Azure 가상 네트워크 실습

# %% [markdown]
# > ##  1) 가상 네트워크 만들기

# %% [markdown]
# >>### (1) 리소스 만들기에서 Virtual Network를 찾아서 만들기

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### (2) 네트워크 정보 설정

# %% [markdown]
# - 리소스 그룹 : 같이 쓰는 클라우드라면 본인 리소스 선택
# - 이름 : 가상네트워크 이름
# - 지역 : 클라우드 위치 지역 (해외 선택해도 무관)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### (3) IPv4 주소 공간

# %% [markdown]
# - 10.2.0.0 부터 10.2.255.255 까지 65536개의 주소 중에 선택할 수 있다

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### (4) 서브넷

# %% [markdown]
# - IP 주소에서 네트워크 영역을 부분적으로 나눈 부분 네트워크

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### (5) 가상 네트워크 완성

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 2) 가상 머신 만들기 (총 2개 만들기)

# %% [markdown]
# ###(1) 가상 머신 만들기

# %% [markdown]
# - 가상머신 만들기 클릭

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### (2) 설정

# %% [markdown]
# - 리소스 그룹 : 공용 클라우드라면 내 리소스 선택
# - 가상 머신 이름 : 임의로 정하면 됨
# - 지역 : 가상 네트워크(virtual network) 만들때와 동일한 지역으로 선택하는 것이 좋음

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - 이미지 : window server2022 datacenter : azure edition - x64 gen2 로 선택
# - 크기 : 비용으로, 안나오는 경우 지역 바꿔야 함

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - 사용자 이름 : 가상 머신 로그인 ID
# - 암호 : 가상 머신 로그인 PW

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - 인바운드 포트에 HTTP(80), RDP(3389) 두개로 연결 예정
# - 가상머신 1 : HTTP(80)에만 연결
# - 가상머신 2 : RDP(3390)에만 연결

# %% [markdown]
# ![image.png](data:image/png;base64,...)
