# %% [markdown]
# <a href="https://colab.research.google.com/github/jhportfolio1/MS-AI-School-Azure-and-Cloud/blob/main/Azure02_IaaS_%EC%8B%A4%EC%8A%B5_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Azure IaaS 실습

# %% [markdown]
# > ##  1) 가상 네트워크 만들기

# %% [markdown]
# >>### (1) 리소스 만들기에서 Virtual Network를 찾아서 만들기

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# >>### (2) 네트워크 정보 설정

# %% [markdown]
# - 리소스 그룹 : 같이 쓰는 클라우드라면 본인 리소스 선택
# - 이름 : 가상네트워크 이름
# - 지역 : 클라우드 위치 지역 (해외 선택해도 무관)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# >>### (3) IPv4 주소 공간

# %% [markdown]
# - 10.2.0.0 부터 10.2.255.255 까지 65536개의 주소 중에 선택할 수 있다

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# >>### (4) 서브넷

# %% [markdown]
# - IP 주소에서 네트워크 영역을 부분적으로 나눈 부분 네트워크

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# >>### (5) 가상 네트워크 완성

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# >## 2) 가상 머신 만들기 (총 2개 만들기)

# %% [markdown]
# >>### (1) 가상 머신 만들기

# %% [markdown]
# - 가상머신 만들기 클릭

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# >>### (2) 설정

# %% [markdown]
# - 리소스 그룹 : 공용 클라우드라면 내 리소스 선택
# - 가상 머신 이름 : 임의로 정하면 됨
# - 지역 : 가상 네트워크(virtual network) 만들때와 동일한 지역으로 선택하는 것이 좋음

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - 이미지 : window server2022 datacenter : azure edition - x64 gen2 로 선택
# - 크기 : 비용으로, 안나오는 경우 지역 바꿔야 함

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - 사용자 이름 : 가상 머신 로그인 ID
# - 암호 : 가상 머신 로그인 PW

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - 인바운드 포트에 HTTP(80), RDP(3389) 두개로 연결 예정
# - 가상머신 1 : HTTP(80), RDP(3390) 연결
# - 가상머신 2 : HTTP(80), RDP(3390) 연결

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - NIC 네트워크 보안그룹 설정에 따라 보안 환경 설정됨

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# >>### (3) 가상머신 2개 완성

# %% [markdown]
# - nsg 는 가상머신 보안 리소스

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# ># 3) 가상머신 연결

# %% [markdown]
# >>### (1) 가상머신에서 공용IP 주소 복사

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# >>### (2) 로컬 검색창에 '원격데스크톱연결' 실행

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# >>### (3) 복사해 둔 IP주소를 입력

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# >>### (4) 가상 머신 만들때 ID/PW 입력

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# >>### (5) 가상머신 안에서 가상머신2 연결

# %% [markdown]
# - 로컬에서 가상머신1 들어간 것 처럼, 가상머신 1에서 '원격데스크톱 연결' 들어간 후 가상머신2 연결

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# >>### (6) 가상머신1, 가상머신2 서로 연결

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - 가상머신1, 가상머신2에서 각각 Powershell 띄운다.
# - Powershell에 New-NetFirewallRule –DisplayName "Allow ICMPv4-In" –Protocol ICMPv4 입력

# %% [markdown]
# ![image.png](data:image/png;base64,...)
