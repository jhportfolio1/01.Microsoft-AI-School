# %% [markdown]
# <a href="https://colab.research.google.com/github/jhportfolio1/MsAiSchool_05_Linux/blob/main/Linux13_%EC%95%A0%ED%94%8C%EB%A6%AC%EC%BC%80%EC%9D%B4%EC%85%98_%ED%81%AC%EA%B8%B0_%EC%A1%B0%EC%A0%95.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. 수동으로 Pod 크기 조정

# %% [markdown]
# - 클러스터에 있는 Pod의 수와 상태 확인

# %%
kubectl get pods

# %% [markdown]
# - 크기조정 (scaling) : 프론트엔드Pod 수를 5개로 늘리기

# %%
kubectl scale --replicas=5 deployment/azure-vote-front

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 2. Pod 자동 크기 조정

# %%
az aks show --resource-group myResourceGroup --name myAKSCluster --query kubernetesVersion --output table

# %%
az aks show --resource-group RG97 --name labuser97aks2 --query kubernetesVersion --output table

# %% [markdown]
# - AKS 클러스터 1.10 이하인 경우 자동설치 어려워서 아래꺼 설치해야 함

# %%
kubectl apply -f https://github.com/kubernetes-sigs/metrics-server/releases/download/v0.3.6/components.yaml

# %% [markdown]
# - POD 수 자동조정 (사용량 50% 초과하면 최대 10개의 인스턴스로 증가 / 최소 3개의 인스턴스 배포)

# %%
kubectl autoscale deployment azure-vote-front --cpu-percent=50 --min=3 --max=10

# %% [markdown]
# - 자동조정 상태 확인

# %%
kubectl get hpa

# %% [markdown]
# # 3. 수동으로 AKS 노드 크기 조정

# %% [markdown]
# - 쿠버네티스 클러스터의 노드 수 3개로 증량

# %%
az aks scale --resource-group myResourceGroup --name myAKSCluster --node-count 3

# %%
az aks scale --resource-group RG97 --name labuser97aks2 --node-count 3
