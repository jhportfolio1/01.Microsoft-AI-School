# %% [markdown]
# <a href="https://colab.research.google.com/github/jhportfolio1/MsAiSchool_05_Linux/blob/main/Linux03_VI_Editor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #1. VI

# %% [markdown]
# >## 1) 실행

# %%
vi test.txt

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# >## 2) 입력모드 : I

# %%
i 엔터

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# >## 3) 나오기 : esc

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# >## 4) 저장하기
# - :w

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# >## 5) 내용추가하기
# - I or A

# %% [markdown]
# >## 6) 나가기

# %% [markdown]
# >>### (1) 저장하고 나가기
# - :wq
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# >>### (2) 저장하지 않고 나가기
# - !q

# %% [markdown]
# >## 7) 저장한 내용 확인하기

# %%
$ ls
$ cat test.txt

# %% [markdown]
# ![image.png](data:image/png;base64,...)
