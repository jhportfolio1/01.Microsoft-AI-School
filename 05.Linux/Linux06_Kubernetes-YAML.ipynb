# %% [markdown]
# <a href="https://colab.research.google.com/github/jhportfolio1/MsAiSchool_05_Linux/blob/main/Linux06_YAML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. YAML Basic

# %% [markdown]
# >## 1) 개념

# %% [markdown]
# - 데이터 직렬화에 쓰이는 포맷/양식 중 하나
# - 데이터 직렬화 : 서비스간 Data 전송할 때 쓰이는 포맷으로 변환하는 작업
# - 다른 데이터 직렬화 포맷 : XML, JSON
# - 파일포맷 : .yaml, .yml

# %% [markdown]
# >## 2) 특징

# %% [markdown]
# - 가독성 : 읽기 쉬움

# %% [markdown]
# # 2. 문법

# %% [markdown]
# >## 1) Key-Value

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# >## 2) 주석 : 앞에 # 붙이기

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# >## 3) 자료형

# %% [markdown]
# >>### (1) String
# - 문자열/숫자열 : 그냥 작성하거나, 따옴표로 감싸면 됨

# %%
this is 1st string
"this is 1st string"

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# >>### (2) 정수형 (integer)
# - 123
# - 0x 로 시작 : ox1ffff

# %% [markdown]
# >>### (3) 실수형(float)
# - 99,9
# - 1.23e+03

# %% [markdown]
# >>### (4) Boolean
# - true / yes / on
# - false / no / off

# %% [markdown]
# >## 4) 자료형

# %% [markdown]
# - ["1", "2", "3"]
# - 문자열/숫자열/실수형/정수형/불리안 모두 가능

# %% [markdown]
# >## 5) 여러줄의 문자열
# - '\n'을 이용하여 처리

# %% [markdown]
# >## 6) Multi document yaml
# - '---' 구분선으로 하나의 yaml 파일에 여러 document 작성 가능

# %% [markdown]
# ![image.png](data:image/png;base64,...)
