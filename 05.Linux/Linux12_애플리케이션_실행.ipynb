# %% [markdown]
# <a href="https://colab.research.google.com/github/jhportfolio1/MsAiSchool_05_Linux/blob/main/Linux12_%EC%95%A0%ED%94%8C%EB%A6%AC%EC%BC%80%EC%9D%B4%EC%85%98_%EC%8B%A4%ED%96%89.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. AKS 에서 애플리케이션 실행

# %% [markdown]
# - ACR 로그인 서버 이름 가져오기

# %%
az acr list --resource-group myResourceGroup --query "[].{acrLoginServer:loginServer}" --output table

# %%
az acr list --resource-group RG97 --query "[].{acrLoginServer:loginServer}" --output table

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - 메니페스트 파일 열기

# %%
vi azure-vote-all-in-one-redis.yaml

# %%
containers:
- name: azure-vote-front
  image: mcr.microsoft.com/azuredocs/azure-vote-front:v1

# %%
containers:
- name: azure-vote-front
  image: labuseracr.azurecr.io/azure-vote-front:v1

# %% [markdown]
# - 애플리케이션 배포

# %%
kubectl apply -f azure-vote-all-in-one-redis.yaml

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - 애플리케이션 테스트

# %%
kubectl get service azure-vote-front --watch

# %%
azure-vote-front   LoadBalancer   10.0.34.242   <pending>     80:30676/TCP   5s

# %%
azure-vote-front   LoadBalancer   10.0.34.242   52.179.23.131   80:30676/TCP   67s

# %% [markdown]
# ![image.png](data:image/png;base64,...)
