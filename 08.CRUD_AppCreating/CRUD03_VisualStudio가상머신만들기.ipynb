# %% [markdown]
# <a href="https://colab.research.google.com/github/jhportfolio1/MsAiSchool08_CRUD_AppCreating/blob/main/CRUD03_VisualStudio%EA%B0%80%EC%83%81%EB%A8%B8%EC%8B%A0%EB%A7%8C%EB%93%A4%EA%B8%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Visual Studio 환경 설정

# %% [markdown]
# >## 1) Visual Studio Community 검색하여 다운로드
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# >## 2) Azure - Visutal Studio 있는 가상환경 설치

# %% [markdown]
# >>### (1) Visual Studio 2022 선택
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# >>### (2) 프로젝트 설정 : 다음과 같이 설정
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# >>### (3) 네트워크 설정
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# >>### (4) 배포 만들기
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# >## 3) 가상머신 로그인 후 한글 패키지 설치

# %% [markdown]
# >>### (1) 가상머신 로그인 : 원격데스크톱 연결
# - 컴퓨터 : VS 가상머신 IP 주소 입력
# - 사용자이름 : 가상머신 ID/PW

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# >>### (2) 윈도우 세팅에서 한국어 설치
# - 세팅
# - Date&Time
# - Language
# - Korean 설치

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# >>### (3) 설치중
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 2. VS 가상머신에서 SSMS 설치

# %% [markdown]
# >## 1) SSMS 설치 방법

# %% [markdown]
# >>>### (1) 설치하는 곳
# - https://learn.microsoft.com/ko-kr/sql/ssms/download-sql-server-management-studio-ssms?view=sql-server-ver16#download-ssms
#
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# >>### (2) 설치완료
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# >>
