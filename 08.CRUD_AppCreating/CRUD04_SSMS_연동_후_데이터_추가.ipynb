# %% [markdown]
# <a href="https://colab.research.google.com/github/jhportfolio1/MsAiSchool08_CRUD_AppCreating/blob/main/CRUD04_SSMS_%EC%97%B0%EB%8F%99_%ED%9B%84_%EB%8D%B0%EC%9D%B4%ED%84%B0_%EC%B6%94%EA%B0%80.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. SSMS(SQL Server Management Studio) 사용하여 연결 및 쿼리

# %% [markdown]
# >## 1) 서버 연결 정보 가져오기

# %% [markdown]
# >>### (1) Azure Portal 로그인 후 쿼리할 데이터베이스로 이동

# %% [markdown]
# >>![image.png](data:image/png;base64,...)

# %% [markdown]
# >>### (2) SQL Database 서버 이름 복사
# >>![image.png](data:image/png;base64,...)

# %% [markdown]
# >>### (3) Azure에서 만든 서버에서 다음과 같이 설정
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# >## 2) 데이터베이스 연결

# %% [markdown]
# >>### (1) SSMS 열어서 로그인
# - 데이터베이스 엔진 설정
# - 서버이름 : Azure Database 개요의 서버이름 복사한 것 붙여넣기
# - SQL Server 설정
# - 로그인 정보 : Database 만들때 ID/PW로 로그인
# - ★가상머신에서 Azure Portal 로그인 필수

# %% [markdown]
# >> ![image.png](data:image/png;base64,...)

# %% [markdown]
# >>### (2) New Database - Option : Korean_Wansung_CI_AS 선택
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# >>### (3) 생성완료
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# >## 3) 테이블 만들기

# %% [markdown]
# >>### (1) 새쿼리 생성 후 아래 쿼리 실행
# - https://www.w3schools.com/sql/sql_create_table.asp

# %% [markdown]
# >> ![image.png](data:image/png;base64,...)

# %%
CREATE TABLE member (
  Idx INT IDENTITY(1,1) PRIMARY KEY,
  Names VARCHAR(45) NOT NULL,
  Addr VARCHAR(100),
  Mobile VARCHAR(13),
  Email VARCHAR(50))

# %% [markdown]
# >>![image.png](data:image/png;base64,...)

# %% [markdown]
# >>- 실행결과 : BookStore 안에 Columns 생성된 게 보임
# >>![image.png](data:image/png;base64,...)

# %% [markdown]
# >> ![image.png](data:image/png;base64,...)

# %% [markdown]
# >>### (2) 기본키 생성 (Primary Key)
# - 엑셀 탭 안에 사람마다 ID를 준다고 할 때, 그 ID의 번호
# - https://www.w3schools.com/sql/sql_primarykey.ASP
# </br></br>
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# >## 4) 데이터 추가
# - https://www.w3schools.com/sql/sql_insert.asp

# %% [markdown]
# >>### (1) INSERT INTO 로 데이터 추가
# - SQL 주석은 -- 으로 작성한다

# %%
INSERT INTO table_name (column1, column2, column3, ...)
VALUES (value1, value2, value3, ...);

# %% [markdown]
# >>![image.png](data:image/png;base64,...)

# %% [markdown]
# >>### (2) 한번에 여러개 데이터 추가

# %%
-- 여러개 추가
INSERT INTO member VALUES
('황동주', '제주시 서귀포시', '010-8956-7423', 'hdj@gmail.com'),
('김효용', '경주시 인왕동', '010-8736-2919', 'khy@hotmail.com'),
('박현수', '공주시 웅진동', '010-9295-6600', 'phs@yahoo.co.kr')

# %% [markdown]
# >>### (3) 테이블 확인1 : 테이블 우클릭 - SelectTop 1000 Rows 클릭
# - 여기서 'dbo'는 '나'를 의미함

# %% [markdown]
# >> ![image.png](data:image/png;base64,...)

# %% [markdown]
# >>![image.png](data:image/png;base64,...)

# %% [markdown]
# >>### (4) 테이블확인2 : Select * from 테이블이름

# %%
select * from member #member는 테이블이름

# %% [markdown]
# >>![image.png](data:image/png;base64,...)
