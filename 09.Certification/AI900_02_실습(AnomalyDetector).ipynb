# %% [markdown]
# <a href="https://colab.research.google.com/github/jhportfolio1/MsAiSchool09_Certification/blob/main/AI900_02_%EC%8B%A4%EC%8A%B5(AnomalyDetector).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Anomaly Detector

# %% [markdown]
# >## 1) Azure Portal에서 Anomaly Detector 리소스 만들기

# %% [markdown]
# >>### (1) Anomaly Detector 리소스 선택
# >>![image.png](data:image/png;base64,...)

# %% [markdown]
# >>### (2) 프로젝트 세부 정보
# - 지역은 EastUS가 어떤 문제도 잘 발생하지 않음
# - 오류성 검사 오류나면 standard 로 체크하면 된다
# >>![image.png](data:image/png;base64,...)

# %% [markdown]
# >>### (3) 배포 완료
# >>![image.png](data:image/png;base64,...)
# </br></br>
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# >## 2) Cloud Shell

# %% [markdown]
# >>### (1) Azure 상단의 Cloud Shell 연결
# >>![image.png](data:image/png;base64,...)

# %% [markdown]
# >>### (2) Powershell 선택
# >>![image.png](data:image/png;base64,...)

# %% [markdown]
# >>### (3) 스토리지 만들기
# >>![image.png](data:image/png;base64,...)

# %% [markdown]
# >>### (4) Azure Powershell 설치 완료
# >>![image.png](data:image/png;base64,...)

# %% [markdown]
# >>### (5) 클라이언트 애플리케이션 구성 및 실행
# - Anomaly Detector 서비스를 사용하여 데이터를 분석하는 간단한 애플리케이션을 실행가능
# - 명령 셸에서 다음 명령을 입력
# - 샘플 애플리케이션 다운로드
# - ai-097이라는 폴더에 저장

# %%
git clone https://github.com/MicrosoftLearning/AI-900-AIFundamentals ai-097

# %% [markdown]
# >>![image.png](data:image/png;base64,...)

# %% [markdown]
# >## 3) 가상머신에서 진행

# %% [markdown]
# >>### (1) Azure VM 만들기
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# >>### (2) 가상머신 접속

# %% [markdown]
# >> - VM 연결 클릭
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# >> - RDP 파일 다운로드 후 다운로드 파일 클릭
# >>![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# >>### (4) 로그인
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# >>### (5) 가상머신 VS Code Studio 및 GIT 설치

# %% [markdown]
# ![image.png](data:image/png;base64,...)![image.png](data:image/png;base64,...)

# %% [markdown]
# >>### (6) 가상머신 VS CODE 깃클론
# - Terminal - New 누르고
# ![image.png](data:image/png;base64,...)

# %%
git clone https://github.com/MicrosoftLearning/AI-900-AIFundamentals ai-097

# %% [markdown]
# >> - 왼쪽에 깃허브 클론된 것이 보임
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# >>### (7) anomalies-ps1 파일에서
# - ket, endpoint 값 입력 (azure anomaly detector 생성한 것)
# - 아래 커맨드 창에 다음과 같이 입력

# %%
cd ai-900
.\detect-anomalies.ps1

# %% [markdown]
# >>![image.png](data:image/png;base64,...)

# %% [markdown]
# >> - 결과
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# >## 4) Postman에서 확인

# %% [markdown]
# >>### (1) Postman 엔드포인트 입력
# - Header에 키값 라벨과 값 추가
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# >>### (2) Body 입력

# %% [markdown]
# >>![image.png](data:image/png;base64,...)
