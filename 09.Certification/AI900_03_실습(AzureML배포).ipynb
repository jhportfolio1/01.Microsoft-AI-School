# %% [markdown]
# <a href="https://colab.research.google.com/github/jhportfolio1/MsAiSchool09_Certification/blob/main/AI900_03_%EC%8B%A4%EC%8A%B5(AzureML%EB%B0%B0%ED%8F%AC).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Azure Machine Learning

# %% [markdown]
# >## 1) Azure ML 리소스 만들기

# %% [markdown]
# >>### (1) Azure ML 만들기
# >>![image.png](data:image/png;base64,...)

# %% [markdown]
# >>### (2) 리소스 세부 정보 및 작업 영역 설정
# >>![image.png](data:image/png;base64,...)

# %% [markdown]
# >>### (3) 배포진행
# >>![image.png](data:image/png;base64,...)

# %% [markdown]
# >## 2) Azure Machine Learning 실습
# - 날씨 예측 ML 만들기

# %% [markdown]
# >>### (1) Compute

# %% [markdown]
# >>- Compute 종류
# >>![image.png](data:image/png;base64,...)

# %% [markdown]
# >>- Compute Cluster 만들기
# >>![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# >> -Computer Cluster 완성
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# >>### (2) Data

# %% [markdown]
# >> - 데이터 만들기
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# >>- 웹에서 데이터 가져오는 경우
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# >> - 가져온 데이터 미리보기
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# >> - 데이터 헤더가 무엇으로 나뉘어져 있는지 설정 가능
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# >> - 데이터셋 완료
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# >## 3) Automated ML

# %% [markdown]
# >>### (1) Automated ML 생성
# >>![image.png](data:image/png;base64,...)

# %% [markdown]
# >>### (2) 설정
# >> ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# >>### (3) 생성 및 완료
# >>![image.png](data:image/png;base64,...)

# %% [markdown]
# >## 4) 학습 후 배포

# %% [markdown]
# >>### (1) 자전거 수요 예측 모델 배포
# - 결과에 최적 모델이 나타나있음
# >>![image.png](data:image/png;base64,...)

# %% [markdown]
# >>### (2) Best Mdoel 선택 후 배포(Deploy)
# - deploy에서 Web Service 클릭
# >>![image.png](data:image/png;base64,...)

# %% [markdown]
# >## 5) 배포된 모델 확인

# %% [markdown]
# >>### (1) Endpoint에서 배포된 모델 확인
# >>![image.png](data:image/png;base64,...)

# %% [markdown]
# >## 6) Postman

# %% [markdown]
# >>### (1) Postman에 주소 입력
# >>![image.png](data:image/png;base64,...)

# %% [markdown]
# >>### (2) Header 입력
# - bearer 한칸 띄고 키 입력
# >>![image.png](data:image/png;base64,...)

# %% [markdown]
# >>### (3) Body - raw 입력
# - Type JSON으로 바꿔줘야 함

# %%
{
  "Inputs": { 
    "data": [
      {
        "day": 1,
        "mnth": 1,   
        "year": 2022,
        "season": 2,
        "holiday": 0,
        "weekday": 1,
        "workingday": 1,
        "weathersit": 2, 
        "temp": 0.3, 
        "atemp": 0.3,
        "hum": 0.3,
        "windspeed": 0.3 
      }
    ]    
  },   
  "GlobalParameters": 1.0
}

# %% [markdown]
# ![image.png](data:image/png;base64,...)
