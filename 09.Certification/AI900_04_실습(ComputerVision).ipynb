# %% [markdown]
# <a href="https://colab.research.google.com/github/jhportfolio1/MsAiSchool09_Certification/blob/main/AI900_04_%EC%8B%A4%EC%8A%B5(ComputerVision).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Computer Vision 실습

# %% [markdown]
# >## 1) Cognitive Service 리소스 만들기
# - Azure 구독에서 Cognitive Services 리소스 만들기

# %% [markdown]
# - ![image.png](data:image/png;base64,...)

# %% [markdown]
# >## 2) VS Code 에 깃클론 된 상태

# %% [markdown]
# >>### (1) 깃클론

# %%
git clone https://github.com/MicrosoftLearning/AI-900-AIFundamentals ai-097

# %% [markdown]
# >>### (2) image analyze 파일에서 Cognitive Service의 key/endpoint 넣기
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# >## 3)Cognitive Services 이용
# - 사이트 : https://customvision.ai
# - 이미지자료 : https://aka.ms/animal-images

# %% [markdown]
# >>### (1) Custom Vision 포털에서 새 프로젝트 만들기
# - 이미지 추가 클릭 후 추출한 파일 선택
# - 태그 : elephant 업로드
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# >>### (2) 이미지 추가 : Giraffe/Lion 이미지 폴더 업로드
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# >>### (3) 학습 - 빠른 훈련

# %% [markdown]
# >## 4) 모델테스트

# %% [markdown]
# > - 성능 지표 위에서 빠른 테스트 를 클릭합니다 .
#
# >- 이미지 URL 상자 에 빠른 테스트 이미지(➔) 버튼을 입력 https://aka.ms/giraffe하고 클릭합니다 .
#
# >- 모델에서 반환된 예측을 봅니다. 기린 의 확률 점수가 다음과 같이 가장 높아야 합니다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# >## 5) 이미지 분류 모델 배포

# %% [markdown]
# >>### (1) publish를 클릭하여 다음 설정으로 학습된 모델을 게시

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# >>### (2) 깃클론
# -다음 명령을 입력하여 이 연습용 파일을 다운로드하고 ai-900 이라는 폴더에 저장

# %%
rm -r ai-900 -f
git clone https://github.com/MicrosoftLearning/AI-900-AIFundamentals ai-097

# %% [markdown]
# >> - 파일을 다운로드한 후 다음 명령을 입력하여 ai-900 디렉토리로 변경하고 이 연습을 위한 코드 파일을 편집

# %%
cd ai-900
code classify-image.ps1

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - 예측 URL 및 예측 키

# %%
$predictionUrl="https..."
$predictionKey ="1a2b3c4d5e6f7g8h9i0j...."

# %% [markdown]
# - 코드에서 변수를 변경한 후 CTRL+S를 눌러 파일을 저장

# %% [markdown]
# - CTRL+Q를 눌러 코드 편집기 닫기

# %% [markdown]
# >## 6) 클라이언트 애플리케이션 테스트
# - 샘플 클라이언트 애플리케이션을 사용하여 포함된 동물을 기반으로 이미지를 분류 가능

# %% [markdown]
# >>### (1) 터미널/cmd에서 아래 명령 실행

# %%
./classify-image.ps1 1

# %%
./classify-image.ps1 2

# %%
./classify-image.ps1 3
