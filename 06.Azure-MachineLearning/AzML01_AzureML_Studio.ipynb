# %% [markdown]
# <a href="https://colab.research.google.com/github/jhportfolio1/MsAiSchool_06_AzureML/blob/main/AzML01_AzureML_Studio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Azure Machine Learning Studio

# %% [markdown]
# >## 1) Azure 포털에서 Azure Machine Learning 리소스 생성

# %% [markdown]
# >## 2) 리소스 배포 완료시 Azure Machine Learning Studio에서 작업
# - 크기가 큰 리소스의 경우 개별적인 작업 공간이 있음

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# >## 3) Compute 생성

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - GPU 가 더 좋지만, 실습용으로 CPU 사용함
#
# ![image.png](data:image/png;base64,...)
