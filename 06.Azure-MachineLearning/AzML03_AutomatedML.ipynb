# %% [markdown]
# <a href="https://colab.research.google.com/github/jhportfolio1/MsAiSchool_06_AzureML/blob/main/AzML03_AutomatedML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Automated ML 사용법

# %% [markdown]
# >## 1) Create

# %% [markdown]
# - Automated ML - Create 클릭

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - Name 설정하고 다음

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - Local File 선택하면 내 데이터 삽입 가능

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - Azure Blob Storage 선택 후

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - 내 데이터 업로드

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - Next 누르면 분석됨

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# >## 2) 데이터 업로드 후 세팅

# %% [markdown]
# - 데이터 업로드 완료

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - Next 누르면 Data Schema : Data 포함 여부 선택 가능
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - 데이터 세팅 완료
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# >## 3) Auto ML 작업 생성

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - AutoML 작업 생성
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - classification / 설정 선택

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - 데이터 학습/검증용 비율 선택

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - Model -> MaxAbsSaler -> Metircs

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
