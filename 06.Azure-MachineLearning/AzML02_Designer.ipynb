# %% [markdown]
# <a href="https://colab.research.google.com/github/jhportfolio1/MsAiSchool_06_AzureML/blob/main/AzML02_Designer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Designer

# %% [markdown]
# >>## 1) Enter Data Manually

# %% [markdown]
# - 드래그에서 보드에 올리면 활용 가능함

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - 데이터 세팅
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - 세팅값 : Compute instance, myML
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - Submit -> Create New

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - 결과
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - 파이프라인에 작업중인 데이터 나타남

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# >>## 2) Split Data

# %% [markdown]
# - 데이터 훈련용/분석용으로 나눔

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - Train Model 완성

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# >## 3) Job Detail (분석작업 상세확인 가능)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# >## 4) Preview Data (결과 확인)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
