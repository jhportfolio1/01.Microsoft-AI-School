# %% [markdown]
# <a href="https://colab.research.google.com/github/jhportfolio1/MS-AI-School-AiBasic/blob/main/AI02_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Data

# %% [markdown]
# ## 1) Steps

# %% [markdown]
# 1.   비즈니스 도메인에 대한 이해
# 2.   비즈니스 문제에 대한 이해
# 3.   적합한 데이터, 적합한 제목, 적합한 알고리즘
# 4.   머신 러닝 지식과 결합

# %% [markdown]
# ## 2) Data

# %% [markdown]
# - 모델 = 알고리즘 + Data

# %% [markdown]
# ###  (1) 선형회귀

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - 근속연수 : X
# - 연봉 : y
# - 연차에 따른 상승폭 : w
# - 초봉 : b

# %% [markdown]
# ### (2) Feature 데이터

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - 타이타닉 호에서 나이, 성별, 선실등급에 따른 생존여부
# - Feature(주요요소) : 나이, 성별, 선실등급
# - Label : 생존여부

# %% [markdown]
# ### (3) 데이터 학습 및 트레이닝

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - 7:3 으로 나누어 학습
# - Train set : 7
# - Test set : 3

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - test 군에 False만 있으면 안되기 때문에, 데이터를 잘 섞어줘야 한다.

# %% [markdown]
# ## 2) Open Data

# %% [markdown]
# ### (1) Kaggle

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - 오픈된 코드 경합장
# - 프로젝트에 대해 누가 더 코딩을 잘하는지 경쟁함

# %% [markdown]
# ### (2) 국가 통계 포털
