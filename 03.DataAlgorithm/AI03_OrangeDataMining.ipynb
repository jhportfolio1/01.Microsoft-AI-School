# %% [markdown]
# <a href="https://colab.research.google.com/github/jhportfolio1/MS-AI-School-AiBasic/blob/main/AI03_OrangeDataMining.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Orange Data Mining

# %% [markdown]
# ## 1) Orange Data Mining

# %% [markdown]
# - 데이터에 대한 지식 없이도 처리, 시각화, 머신러닝 직접 해볼 수 있음
# - 대학/전문가 본격 개발 전 데이터 검증 용도로 활용함
# - GPL 라이선스
# - 위젯으로 다양한 기능을 제공함
# - 파이썬 라이브러리(Numpy, Scipy, scikit-learn) 활용할 수 있음
# - py QT : 파이썬으로 UI 프로그램 짤 수 있는 프로그램

# %% [markdown]
# ## 2) Orange Data Mining 주요 기능

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - Data : 기본 데이터 다루는 기능
# - Transform : 데이터 활용 기능
# - Visualize : 데이터 차트화, 시각화
# - Evaluate : 선형회귀 등
# - Unsupervised : 비지도학습 (변칙처리 등)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - 아이콘을 오른쪽으로 끌어오면 위젯화할 수 있음

# %% [markdown]
# # 2. 실습

# %% [markdown]
# ## 1) 엑셀에 데이터 저장

# %% [markdown]
# ### (1) 연봉체계를 엑셀파일로 작성한다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### (2) 엑셀 샘플을 CSV 파일로 저장한다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### (3) Orange에서 연봉체계 샘플 CSV 파일을 연다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)[링크 텍스트](https://)

# %% [markdown]
# ### (4) y가 feature로 되어있으니, target(=label)으로 바꾼다!

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - 아래 숫자는 표시될 데이터를 나타낸다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### (5) apply를 누른다.

# %% [markdown]
# ## 2) 데이터 분석

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### (1) Data Table 위젯으로 가져와서, File에서 Data Table을 잇는다.

# %% [markdown]
# ![image.png](data:image/png;base64,...![image.png](data:image/png;base64,...))![image.png](data:image/png;base64,...)

# %% [markdown]
# - Data Table을 더블클릭하면 아래처럼 표로 나타난다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### (2) Visualize에서 Scatter Plot 가져와서 File과 연결후, 더블클릭

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - Show regression line 을 클릭하면, 선형이 나타남

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 3) 데이터 학습

# %% [markdown]
# ### (1) Model에서 Linear Regression 에 연결

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### (2) Model은 동시에 여러개로 분석가능하다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 4) 데이터 예측

# %% [markdown]
# ### (1) Evaluate의 Prediction 가져오기

# %% [markdown]
# - 학습한 Mdoel과 Evaluate을 연결한다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### (2) 예측하고자 하는 자료 만들기

# %% [markdown]
# - 근속연수에 따른 연봉을 예측해보기 위해, X축만 새로 데이터를 만든다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### (3) File 위젯을 하나 더 끌어와서, 새로만든 파일을 업로드 한다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### (4) 새로운 File 위젯과 Prediction 위젯을 연결한다.

# %% [markdown]
# - Linear Regression에서 Model 이 입력되고
# - File(1)에서 새로운 Data가 입력된다

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### (5) 근속연수(x)에 따른 연봉정보(y)에 대한 예측 확인이 가능하다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - model을 2개로 넣은 경우, 예측도 2개로 나타난다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 5) 예측된 데이터 시각화

# %% [markdown]
# - Visaulize 위젯을 가져와서 Prediction에 연결하면 시각화가 가능하다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 3. Orange 기타 기능

# %% [markdown]
# ## 1) Data

# %% [markdown]
# ### (1) CSV File Import : 파일 언어 등 선택 가능

# %% [markdown]
# ###(2) Datasets : 유명한 데이터 모아놓은 것으로, 다운 받을 수 있음

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - 원하는 데이터 더블클릭으로 다운받고, Data Table과 연결하면 차트 볼 수 있음

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 4. 추가분석 : 보스턴 데이터 집값

# %% [markdown]
# ## 1) Datasets 에서 Housing 을 다운받아서 DataTable과 연결한다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - MEDV : 집값으로 Lable 데이터
# - CRIM 이후 데이터 : 집값에 영향주는 features

# %% [markdown]
# ## 2) Datatable을 Scatterplot과 연결한다

# %% [markdown]
# - Scatterplot 에서 X, Y 축을 설정하면 상관관계를 알 수 있다

# %% [markdown]
# ### (1) 범죄율에 따른 집값

# %% [markdown]
# - 범죄율이 낮을수록 집값이 높음

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### (2) 찰스강과 가까운 여부에 따른 집값

# %% [markdown]
# - 찰스강은 큰 영향 없음

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### (3) 방 갯수에 따른 집값

# %% [markdown]
# - 방 갯수가 많은 수록 집값 상승

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### (4) 세금에 따른 집값

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 3) 보스턴 집값 데이터 학습 및 예측

# %% [markdown]
# ### (1) 학습 및 예측하기
# - Linear Regression을 이용해 학습하고, Prediction으로 예측한다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### (2) Neural Network Model로 예측하기

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - MSE 가 낮을 수록 더 신뢰도가 높다
# - 만약 수치가 비슷하게 나온다면, Neural Network 값을 높여주면 확 차이가 난다.
# - AdaBoost로 Model을 추가하면, 더 신뢰성 높은 값을 얻을 수 있다.
