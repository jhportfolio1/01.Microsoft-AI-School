# %% [markdown]
# <a href="https://colab.research.google.com/github/jhportfolio1/MsAiSchool10_StatisticalData/blob/main/DATA01_Anaconda_Setting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. 통계기반분석데이터 위한 아나콘다 환경 세팅

# %% [markdown]
# >## 1) 아나콘다 설치

# %% [markdown]
# >>### (1) 아나콘다?
# - 머신러닝이나 데이터분석 등에 사용하는 여러가지 패키지가 기본적으로 포함되어 있는 파이썬 배포판
# - 파이썬 가상 환경 구축

# %% [markdown]
# >>### (2) 아나콘다 설치
# - 설치링크 : https://www.anaconda.com/download
# - 윈도우의 경우 파이썬 이미 설치되어 있는 경우 삭제 후 아나콘다 설치 필요
# - 아래 설정이 꼭 체크되도록 설정 후 다운로드
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# >## 2) 아나콘다 실행

# %% [markdown]
# >>### (1) 아나콘다 프롬프트 관리자 실행
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# >>### (2) 환경명 / 파이썬 설치

# %%
conda create -n AI python=3.8

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# >>### (3) 생성된 가상환경에 접속

# %%
conda activate AI

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#경로설정 / 바탕화면에 새폴더 만들어서 윗부분 주소 복사

cd 주소

# %%
#jhportfolio1 이라는 새폴더를 만들었다고 할 때

cd C:\Users\jhmz1\Desktop\jhportfolio1

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# >>### (4) 가상환경에 jupyter notebook 주피터노트북 설치

# %%
python -m ipykernel install --user --name test1 --display-name test1

# %%
#가상환경명이 AI이면
python -m ipykernel install --user --name AI --display-name AI

# %% [markdown]
# >>### (5) 주피터 노트북 실행

# %%
jupyter notebook

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
